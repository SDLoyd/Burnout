# %% [markdown]
# <h3><center>Corporate Burnout Regression</center></h3>
#
#
# <center>Sam Loyd</center>
# <center>June 2021</center>

# %%
# Required Modules
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from imblearn.over_sampling import *
from imblearn.combine import SMOTETomek
from collections import Counter
from pycaret.regression import *
from sklearn import metrics
from sklearn.impute import KNNImputer
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import r2_score
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ## Data Analysis - EDA

# %%
# Pull in data for stroke data 
train_df = pd.read_csv("data\\train.csv")
# test_df = pd.read_csv("data\\test.csv")

# %%
# Setup frame
# frames = [train_df, test_df]

# %%
# Join them
# burnout_df = pd.concat(frames)

# Test data has no target variables
burnout_df = train_df

# %%
# First look
burnout_df.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No      2.00000              3.00000               3.80000
# 1                 Yes      1.00000              2.00000               5.00000
# 2                 Yes      2.00000                  nan               5.80000
# 3                 Yes      1.00000              1.00000               2.60000
# 4                  No      3.00000              7.00000               6.90000
#
#    Burn Rate
# 0    0.16000
# 1    0.36000
# 2    0.49000
# 3    0.20000
# 4    0.52000

# %%
burnout_df.dtypes
# Out:
# Employee ID              object
# Date of Joining          object
# Gender                   object
# Company Type             object
# WFH Setup Available      object
# Designation             float64
# Resource Allocation     float64
# Mental Fatigue Score    float64
# Burn Rate               float64
# dtype: object

# %%
burnout_df['Julian Date'] = pd.DatetimeIndex(burnout_df['Date of Joining']).to_julian_date()
burnout_df['Date of Joining'] =  pd.to_datetime(burnout_df['Date of Joining'], infer_datetime_format=True)

# %%
# Apply profie and create html report
# Commented out for performance
# prof = ProfileReport(burnout_df,title="Pandas Profiling Report - Burnout Data", explorative=True)
# prof.to_file(output_file='burnout-pandas-profile-report.html')

# Please see stroke-pandas-profile-report.html for a full analysis

# %% [markdown]
# ### [Pandas report](https://sdloyd.github.io/Stroke/pandasprofile/stroke-pandas-profile-report.html)

# %%
# Pandas-profiling is lacking in outlier analysis visuals so those are included here.
# Only mental fatigue score shows outliers

# Box and whisker plots for outlier analysis.
boxplot = burnout_df.boxplot(column=['Designation','Resource Allocation','Mental Fatigue Score','Burn Rate'],rot=90)

# %% [markdown]
# ## Data Wrangling
# Impute missing values found in the EDA process using pandas-profile report and remove rows missing target variable.

# %%
# Take a look - saw no significant reason to standardize or normalize based on the max values
burnout_df.describe()
# Out:
#        Designation  Resource Allocation  Mental Fatigue Score   Burn Rate  \
# count  22750.00000          21369.00000           20633.00000 21626.00000
# mean       2.17873              4.48140               5.72819     0.45201
# std        1.13514              2.04721               1.92084     0.19823
# min        0.00000              1.00000               0.00000     0.00000
# 25%        1.00000              3.00000               4.60000     0.31000
# 50%        2.00000              4.00000               5.90000     0.45000
# 75%        3.00000              6.00000               7.10000     0.59000
# max        5.00000             10.00000              10.00000     1.00000
#
#         Julian Date
# count   22750.00000
# mean  2454648.89451
# std       105.34819
# min   2454466.50000
# 25%   2454557.50000
# 50%   2454649.50000
# 75%   2454739.50000
# max   2454831.50000

# %%
# Gather mins
min_df = pd.to_datetime(burnout_df['Date of Joining'].min())

# %%
# Look at data types
burnout_df.dtypes
# Out:
# Employee ID                     object
# Date of Joining         datetime64[ns]
# Gender                          object
# Company Type                    object
# WFH Setup Available             object
# Designation                    float64
# Resource Allocation            float64
# Mental Fatigue Score           float64
# Burn Rate                      float64
# Julian Date                    float64
# dtype: object

# %%
# Convert outlier to min value
burnout_df["Mental Fatigue Score"]=np.where(burnout_df["Mental Fatigue Score"] < 1, 1, burnout_df["Mental Fatigue Score"])

# %%
burnout_df["Mental Fatigue Score"]
# Out:
# 0       3.80000
# 1       5.00000
# 2       5.80000
# 3       2.60000
# 4       6.90000
#           ...
# 22745       nan
# 22746   6.70000
# 22747       nan
# 22748   5.90000
# 22749   7.80000
# Name: Mental Fatigue Score, Length: 22750, dtype: float64

# %%
# Didn't help model
# Determine how long relative to others
# burnout_df['Relative Tenure'] = (burnout_df['Date of Joining'] - min_df).dt.days

# %%
burnout_df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No      2.00000              3.00000
# 1                     Yes      1.00000              2.00000
# 2                     Yes      2.00000                  nan
# 3                     Yes      1.00000              1.00000
# 4                      No      3.00000              7.00000
# ...                   ...          ...                  ...
# 22745                  No      1.00000              3.00000
# 22746                 Yes      3.00000              6.00000
# 22747                 Yes      3.00000              7.00000
# 22748                  No      2.00000              5.00000
# 22749                  No      3.00000              6.00000
#
#        Mental Fatigue Score  Burn Rate   Julian Date
# 0                   3.80000    0.16000 2454739.50000
# 1                   5.00000    0.36000 2454800.50000
# 2                   5.80000    0.49000 2454535.50000
# 3                   2.60000    0.20000 2454773.50000
# 4                   6.90000    0.52000 2454671.50000
# ...                     ...        ...           ...
# 22745                   nan    0.41000 2454830.50000
# 22746               6.70000    0.59000 2454484.50000
# 22747                   nan    0.72000 2454775.50000
# 22748               5.90000    0.52000 2454475.50000
# 22749               7.80000    0.61000 2454471.50000
#
# [22750 rows x 10 columns]

# %%
# Count nulls
burnout_df.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# Julian Date                0
# dtype: int64

# %%
# Since burnrate is the target removing any rows missing burnrate
burnout_df.dropna(subset=['Burn Rate'], inplace=True)

# %%
# Separate target variable before imputation to avoid future data concerns
knn_df = burnout_df.drop(['Burn Rate'], axis=1)

# %%
# Impute with K nearest
impute = KNNImputer(n_neighbors = 6, weights = 'uniform')
knn_df['Resource Allocation'] = impute.fit_transform(knn_df[['Resource Allocation']])
knn_df['Mental Fatigue Score'] = impute.fit_transform(knn_df[['Mental Fatigue Score']])

# %%
# New Frame
clean_burnout_df = knn_df

# %%
# Add target back
clean_burnout_df['Burn Rate'] = burnout_df['Burn Rate']

# %%
# Given ranges scale values
sc = MinMaxScaler()
cols = ['Designation','Resource Allocation','Mental Fatigue Score','Julian Date']
clean_burnout_df[cols] = sc.fit_transform(clean_burnout_df[cols])

# %%
# First look
clean_burnout_df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No      0.40000              0.22222
# 1                     Yes      0.20000              0.11111
# 2                     Yes      0.40000              0.38709
# 3                     Yes      0.20000              0.00000
# 4                      No      0.60000              0.66667
# ...                   ...          ...                  ...
# 22745                  No      0.20000              0.22222
# 22746                 Yes      0.60000              0.55556
# 22747                 Yes      0.60000              0.66667
# 22748                  No      0.40000              0.44444
# 22749                  No      0.60000              0.55556
#
#        Mental Fatigue Score  Julian Date  Burn Rate
# 0                   0.31111      0.74795    0.16000
# 1                   0.44444      0.91507    0.36000
# 2                   0.53333      0.18904    0.49000
# 3                   0.17778      0.84110    0.20000
# 4                   0.65556      0.56164    0.52000
# ...                     ...          ...        ...
# 22745               0.52695      0.99726    0.41000
# 22746               0.63333      0.04932    0.59000
# 22747               0.52695      0.84658    0.72000
# 22748               0.54444      0.02466    0.52000
# 22749               0.75556      0.01370    0.61000
#
# [21626 rows x 10 columns]

# %%
# Count nulls
clean_burnout_df.isnull().sum()
# Out:
# Employee ID             0
# Date of Joining         0
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# Julian Date             0
# Burn Rate               0
# dtype: int64

# %%
# Binary values
# 1 unknown, but I made it female since it was the most common
clean_burnout_df['Gender'] = np.where(clean_burnout_df['Gender']=='Male', 1, 0)
clean_burnout_df['Company Type'] = np.where(clean_burnout_df['Company Type']=='Product', 1, 0)
clean_burnout_df['WFH Setup Available'] = np.where(clean_burnout_df['WFH Setup Available']=='True', 1, 0)

# %%
# Any impact on stats - looks acceptable 
clean_burnout_df.describe()
# Out:
#            Gender  Company Type  WFH Setup Available  Designation  \
# count 21626.00000   21626.00000          21626.00000  21626.00000
# mean      0.47522       0.34690              0.00000      0.43575
# std       0.49940       0.47599              0.00000      0.22709
# min       0.00000       0.00000              0.00000      0.00000
# 25%       0.00000       0.00000              0.00000      0.20000
# 50%       0.00000       0.00000              0.00000      0.40000
# 75%       1.00000       1.00000              0.00000      0.60000
# max       1.00000       1.00000              0.00000      1.00000
#
#        Resource Allocation  Mental Fatigue Score  Julian Date   Burn Rate
# count          21626.00000           21626.00000  21626.00000 21626.00000
# mean               0.38709               0.52695      0.49962     0.45201
# std                0.22075               0.19995      0.28872     0.19823
# min                0.00000               0.00000      0.00000     0.00000
# 25%                0.22222               0.41111      0.24658     0.31000
# 50%                0.38709               0.52695      0.50137     0.45000
# 75%                0.55556               0.65556      0.74795     0.59000
# max                1.00000               1.00000      1.00000     1.00000

# %%
clean_burnout_df
# Out:
#                     Employee ID Date of Joining  Gender  Company Type  \
# 0      fffe32003000360033003200      2008-09-30       0             0
# 1          fffe3700360033003500      2008-11-30       1             0
# 2      fffe31003300320037003900      2008-03-10       0             1
# 3      fffe32003400380032003900      2008-11-03       1             0
# 4      fffe31003900340031003600      2008-07-24       0             0
# ...                         ...             ...     ...           ...
# 22745  fffe31003500370039003100      2008-12-30       0             0
# 22746  fffe33003000350031003800      2008-01-19       0             1
# 22747          fffe390032003000      2008-11-05       1             0
# 22748  fffe33003300320036003900      2008-01-10       0             0
# 22749      fffe3400350031003800      2008-01-06       1             1
#
#        WFH Setup Available  Designation  Resource Allocation  \
# 0                        0      0.40000              0.22222
# 1                        0      0.20000              0.11111
# 2                        0      0.40000              0.38709
# 3                        0      0.20000              0.00000
# 4                        0      0.60000              0.66667
# ...                    ...          ...                  ...
# 22745                    0      0.20000              0.22222
# 22746                    0      0.60000              0.55556
# 22747                    0      0.60000              0.66667
# 22748                    0      0.40000              0.44444
# 22749                    0      0.60000              0.55556
#
#        Mental Fatigue Score  Julian Date  Burn Rate
# 0                   0.31111      0.74795    0.16000
# 1                   0.44444      0.91507    0.36000
# 2                   0.53333      0.18904    0.49000
# 3                   0.17778      0.84110    0.20000
# 4                   0.65556      0.56164    0.52000
# ...                     ...          ...        ...
# 22745               0.52695      0.99726    0.41000
# 22746               0.63333      0.04932    0.59000
# 22747               0.52695      0.84658    0.72000
# 22748               0.54444      0.02466    0.52000
# 22749               0.75556      0.01370    0.61000
#
# [21626 rows x 10 columns]

# %%
# No need to pass to model, just an ID
model_burnout_df = clean_burnout_df.drop(['Employee ID','Date of Joining'], axis=1)

# %%
# Split the validation and train data - Pycaret will split out the test
# Create X from the features
X = model_burnout_df.drop(columns=['Burn Rate'])

# Create y from output
y = model_burnout_df[['Burn Rate']]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.40, random_state=1)

# %%
# PyCaret requires them in one dataframe
X_train_caret_reg = X_train.copy()
X_train_caret_reg['Burn Rate'] = y_train['Burn Rate']
X_train_caret_reg
# Out:
#        Gender  Company Type  WFH Setup Available  Designation  \
# 11215       0             0                    0      0.60000
# 4585        0             0                    0      0.80000
# 21893       0             0                    0      0.60000
# 21891       0             0                    0      0.60000
# 13160       0             0                    0      0.20000
# ...       ...           ...                  ...          ...
# 11507       0             0                    0      0.40000
# 18190       0             0                    0      0.60000
# 5434        0             0                    0      0.60000
# 12790       1             1                    0      0.00000
# 250         0             0                    0      0.00000
#
#        Resource Allocation  Mental Fatigue Score  Julian Date  Burn Rate
# 11215              0.44444               0.57778      0.27397    0.59000
# 4585               0.66667               0.84444      0.67671    0.88000
# 21893              0.55556               0.64444      0.12603    0.55000
# 21891              0.44444               0.40000      0.56986    0.28000
# 13160              0.00000               0.52695      0.24384    0.26000
# ...                    ...                   ...          ...        ...
# 11507              0.55556               0.68889      0.16986    0.58000
# 18190              0.33333               0.42222      0.47397    0.39000
# 5434               0.44444               0.28889      0.79178    0.24000
# 12790              0.00000               0.27778      0.58356    0.18000
# 250                0.00000               0.00000      0.29041    0.00000
#
# [12975 rows x 8 columns]

# %%
# Prepare model
exp_clf_reg = setup(X_train_caret_reg, target='Burn Rate', silent=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_6882abfa_f7ec_11eb_9ef5_005056c00008" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6882abfa_f7ec_11eb_9ef5_005056c00008level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row0_col1" class="data row0 col1" >1748</td>
#             </tr>
#             <tr>
#                         <th id="T_6882abfa_f7ec_11eb_9ef5_005056c00008level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row1_col1" class="data row1 col1" >Burn Rate</td>
#             </tr>
#             <tr>
#                         <th id="T_6882abfa_f7ec_11eb_9ef5_005056c00008level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row2_col1" class="data row2 col1" >(12975, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_6882abfa_f7ec_11eb_9ef5_005056c00008level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_6882abfa_f7ec_11eb_9ef5_005056c00008row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T
0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col0" class="data row7 col0" >0.0479</td>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col1" class="data row7 col1" >0.0036</td>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col2" class="data row7 col2" >0.0599</td>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col3" class="data row7 col3" >0.9146</td>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col4" class="data row7 col4" >0.0413</td>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row7_col5" class="data row7 col5" >0.1503</td>
#             </tr>
#             <tr>
#                         <th id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b04a8d44_f7ec_11eb_8ca4_005056c00008row8_col0" class="data row8 col0" >0.0490</td>
#                         <td id

# %%
# Finalize the model
final_model = finalize_model(tuned_model_pick)

# %%
# predict validation data
val_predictions = predict_model(final_model, data=X_val)
val_predictions.Label
# Out:
# 10357   0.19498
# 9443    0.51604
# 20516   0.43732
# 8902    0.35328
# 12396   0.25007
#           ...
# 22657   0.49825
# 14423   0.37022
# 5167    0.84002
# 19732   0.57697
# 19714   0.39473
# Name: Label, Length: 8651, dtype: float64

# %%
# Validation Stats
mae = metrics.mean_absolute_error(y_val, val_predictions.Label)
mse = metrics.mean_squared_error(y_val, val_predictions.Label)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(y_val, val_predictions.Label)

print("Results:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results:
# MAE: 0.04759109523288288
# MSE: 0.003637730266321406
# RMSE: 0.060313599348085715
# R-Squared: 0.9066916542727879

# %%
# Save the model as a pickle file
filename = 'pickle/burnout_primary_model.pickle'
pickle.dump(final_model, open(filename, 'wb'))

# %%
# Save model in pycaret format
save_model(final_model, 'model/burnout_primary_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='Burn Rate',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='Burn Rate')),
#                  ('fix_perfect', Remove_100(target='Burn Rate')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   <catboost.core.CatBoostRegressor object at 0x000001FE22E817C0>]],
#           verbose=False),
#  'model/burnout_primary_model.pkl')
